# %%
# !pip install espnet
# !pip install parallel_wavegan

# %%
import os
import librosa
from IPython.display import Audio, display
from espnet2.bin.tts_inference import Text2Speech
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package cmudict to /root/nltk_data...
# [nltk_data]   Unzipping corpora/cmudict.zip.

# %%
# !pip install -U --no-cache-dir gdown --pre

# %%
import gdown

# %%
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1o6Yd5Gr9Ff7o_XsqTTgy-gU6azkwwDu9/view?usp=share_link
# !gdown --no-cookies --fuzzy https://drive.google.com/file/d/1FbH4zkSqu3I9ZK5tvIEdmBv82Egcnx0x/view?usp=share_link
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1o6Yd5Gr9Ff7o_XsqTTgy-gU6azkwwDu9
# To: /content/iitm.zip
# 100% 108M/108M [00:00<00:00, 176MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1FbH4zkSqu3I9ZK5tvIEdmBv82Egcnx0x
# To: /content/custom.zip
# 100% 107M/107M [00:00<00:00, 205MB/s]

# %%
# !unzip 'iitm.zip' -d ./model_data/
# !unzip 'custom.zip' -d ./model_data2/

# %%
os.chdir('model_data')
speaker1_config = "./exp/tts_train_raw_char/config.yaml"
speaker1_model = "./exp/tts_train_raw_char/train.loss.ave_5best.pth"
print(f"Loading {speaker1_model}")
# Out:
# Loading ./exp/tts_train_raw_char/train.loss.ave_5best.pth

# %%
os.chdir('../model_data2')
speaker2_config = "./exp/tts_train_raw_char/config.yaml"
speaker2_model = "./exp/tts_train_raw_char/train.loss.ave_3best.pth"
print(f"Loading {speaker2_model}")
# Out:
# Loading ./exp/tts_train_raw_char/train.loss.ave_3best.pth

# %%
tts1 = Text2Speech.from_pretrained(train_config=speaker1_config, model_file=speaker1_model, vocoder_tag="parallel_wavegan/vctk_style_melgan.v1")
tts2 = Text2Speech.from_pretrained(train_config=speaker2_config, model_file=speaker2_model, vocoder_tag="parallel_wavegan/vctk_style_melgan.v1")

# %%
tts = "tts1" #@param ['tts1', 'tts2']

# %% [markdown]
# IITM model

# %%
sentence  = input("enter text: ")
wav = tts1(sentence)["wav"]
display(Audio(wav.numpy(), rate=tts1.fs))
# Out:
# enter text: कि जल्दी ही उसमें चश्मे का पेड़ निकल आएगा
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Custom Dataset model

# %%
sentence = input("enter text: ")
wav = tts1(sentence)["wav"]
display(Audio(wav.numpy(), rate=tts1.fs))
